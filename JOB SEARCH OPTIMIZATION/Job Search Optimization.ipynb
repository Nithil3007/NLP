# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import *
from sklearn import preprocessing
from sklearn import metrics

# %%
df = pd.read_csv('gsearch_jobs 2.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'title', 'company_name', 'location', 'via',
#        'description', 'extensions', 'job_id', 'thumbnail', 'posted_at',
#        'schedule_type', 'work_from_home', 'salary', 'search_term', 'date_time',
#        'search_location', 'commute_time', 'salary_pay', 'salary_rate',
#        'salary_avg', 'salary_min', 'salary_max', 'salary_hourly',
#        'salary_yearly', 'salary_standardized', 'description_tokens'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0  index                                              title  \
# 0           0      0                                       Data Analyst
# 1           1      1                                       Data Analyst
# 2           2      2                             Marketing Data Analyst
# 3           3      3  Boolean Search Data Analyst | $54,000-$108,000...
# 4           4      4    Product Data Analyst - Ditch Witch - Now Hiring
#
#             company_name                location           via  \
# 0            Robert Half    Oklahoma City, OK     via LinkedIn
# 1  Apex Health Solutions        United States     via LinkedIn
# 2         Ledger Bennett               Anywhere   via LinkedIn
# 3                IT Pros               Anywhere     via Indeed
# 4       The Toro Company            Perry, OK     via Snagajob
#
#                                          description  \
# 0  Description\n\nRobert Half is looking for a pr...
# ...

# %%
df.shape
# Out:
# (24210, 27)

# %%
titles = df.title
titles_buf = []
for title in titles:
    if title not in titles_buf:
        titles_buf.append(title)
len(titles_buf)
# Out:
# 9430

# %%
titles_buf[:100]
# Out:
# ['Data Analyst',
#  'Marketing Data Analyst',
#  'Boolean Search Data Analyst | $54,000-$108,000+ | Forbes Top 100...',
#  'Product Data Analyst - Ditch Witch - Now Hiring',
#  'Associate Benefits Data Analyst - Remote in Little Rock',
#  'Experienced Data Analyst Required: Dynamic Data Visualization and...',
#  'Clinical Data Analyst (Admin)',
#  'Data Analyst III',
#  'Data Analyst (Remote)',
#  'Data Analyst - open to recent college grads (SEQUEL Software...',
#  'Master Data Analyst',
#  'Data Analyst II',
#  'Data Analyst - HR Analytics (H)',
#  'Data Analyst - Global Learning Management',
#  'Operations Data Analyst',
#  'Location  Price Data Analyst',
#  'Data Analyst - Remote ($67800.00 - $133100.00 / year)',
#  'Operational Systems Analyst (Data Analyst)',
#  'Data Analyst required - Contract to Hire',
#  'Business Systems Data Analyst',
#  'Azure Data Analyst/Modelers/Architect',
#  'Data Governance Analyst II / Oklahoma City, OK',
#  'Data Analyst - Mid',
# ...

# %%
print(df.description[40])
# Out:
# Talentify helps candidates around the world to discover and stay focused on the jobs they want until they can complete a full application in the hiring company career page/ATS.
#
# For those who want to invent the future of health care, here's your opportunity. We're going beyond basic care to health programs integrated across the entire continuum of care. Join us and help people live healthier... lives while doing your life's best work.(sm)
#
# ...

# %%
df.drop(['Unnamed: 0','job_id','thumbnail'],axis = 1)
# Out:
#        index                                              title  \
# 0          0                                       Data Analyst
# 1          1                                       Data Analyst
# 2          2                             Marketing Data Analyst
# 3          3  Boolean Search Data Analyst | $54,000-$108,000...
# 4          4    Product Data Analyst - Ditch Witch - Now Hiring
# ...      ...                                                ...
# 24205   1477                     Marketing Data & BI Analyst II
# 24206   1478                                  Lead-Data Analyst
# 24207   1479                                  Lead-Data Analyst
# 24208   1480                                  Lead-Data Analyst
# 24209   1481  Institutional Credit Management - Lending Data...
#
#                 company_name                location                    via  \
# 0                Robert Half    Oklahoma City, OK              via LinkedIn
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'title', 'company_name', 'location', 'via',
#        'description', 'extensions', 'job_id', 'thumbnail', 'posted_at',
#        'schedule_type', 'work_from_home', 'salary', 'search_term', 'date_time',
#        'search_location', 'commute_time', 'salary_pay', 'salary_rate',
#        'salary_avg', 'salary_min', 'salary_max', 'salary_hourly',
#        'salary_yearly', 'salary_standardized', 'description_tokens'],
#       dtype='object')
